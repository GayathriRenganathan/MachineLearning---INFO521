# %% [markdown]
# ## Course Information
# INFO 521: Introduction to Machine Learning\
# Instructor: Xuan Lu, College of Information Science

# %% [markdown]
# ## Instructions
# #### Objectives
# This worksheet will assess your knowledge of basic commands in Python. Please review the lectures, suggested readings, and additional resources before starting the homework, as this document closely follows the provided materials.
#
# #### Grading
# Please note that grades are **NOT exclusively based on your final answers**. We will be grading the overall structure and logic of your code. Feel free to use as many lines as you need to answer each of the questions. I also highly recommend and strongly encourage adding comments (`#`) to your code. Comments will certainly improve the reproducibility and readability of your submission. Commenting your code is also good coding practice. **Specifically for the course, you’ll get better feedback if the TA is able to understand your code in detail.**
#
# __Total score__: 100 points, with an additional 10 points available for extra credit.
#
# #### Submission
# This homework is due by the end of the week it is released (**Sunday, 11:59 pm AZ time**). Please contact the instructor if you are (i) having issues opening the assignment, (ii) not understanding the questions, or (iii) having issues submitting your assignment. Note that late submissions are subject to a penalty (see late work policies in the syllabus).
# - Please submit a single Jupyter Notebook file (this file). Answers to each question should be included in the relevant block of code (see below). Rename your file to "**lastname_Hw2.ipynb**" before submitting. If a given block of code is causing issues and you didn't manage to fix it, please add comments.
#
# #### Time commitment
# Please reach out if you’re taking more than ~18h to complete (1) this homework, (2) reading the book chapters, and (3) going over the lectures. I will be happy to provide accommodations if necessary. **Do not wait until the last minute to start working on this homework**. In most cases, working under pressure will certainly increase the time needed to answer each of these questions and the instructor and the TA might not be 100% available on Sundays to troubleshoot with you.
#
# #### Looking for help?
# First, please go over the relevant readings for this week. Second, if you’re still struggling with any of the questions, do some independent research (e.g. stackoverflow is a wonderful resource). Don’t forget that your classmates will also be working on the same questions - reach out for help (check under the Discussion forum for folks looking to interact with other students in this class or start your own thread). Finally, the TA is available to answer any questions during office hours and via email.

# %% [markdown]
# ## Questions
# #### Author:
# Name: [Gayathri Renganathan]\
# Affiliation: [iSchool]

# %% [markdown]
# ### Conceptual

# %% [markdown]
# #### Question 1
#
# For each of four scenarios listed below, indicate whether we would generally expect the performance of a flexible statistical learning method to be better or worse than an inflexible method. Justify your answer.
#
# - The sample size (number of observations; n) is extremely large, and the number of predictors (features; p) is small.
#
# > **_Answer:_**  Flexible methods perform well in this case. As the sample size is extremely large, it provides more data for the flexible models to better understand the relationship of the predictors. This helps in providing better accuracy compared to the inflexible models in this case.
#
# - The number of predictors (p) is extremely large, and the number of observations (n) is small.
#
# > **_Answer:_**  Inflexible methods perform well in this case. As the number of predictors is extremely large,  flexible models require more samples to better understand the relationship of the predictors. Considering the sample size is small,  flexible models struggle in providing better accuracy compared to the inflexible models in this case. So inflexible models would be better choice for this case.
#
# - The relationship between the predictors and response is highly non-linear.
#
# > **_Answer:_**  Flexible models works well, with more degrees of freedom. The degrees of freedom is a quantity that summarizes the flexibility of a curve. Inflexible models with very less degree of freedom does not work well in this case.
#
# - The variance of the error terms (i.e. $σ^2 = Var(ϵ)$) is extremely high.
#
# > **_Answer:_**  Inflexible models works well. With the variance of error is extremely high, the flexible models will try to follow the error. So Inflexible models is better for this case.

# %% [markdown]
# #### Question 2
#
# In a few sentences, please answer the following questions to the best of your knowledge. Feel free to conduct additional research and cite your sources.
#
# - Briefly explain the “curse of dimensionality”, provide a hypothetical example illustrating the concept, and list at least one potential way that is generally used to handle it when using machine learning models.
#
# > **_Answer:_**  Curse of dimensionality is a condition when the dataset has very high number of predictors. When the dataset has very high dimensions, the machine learning models needs more data to come at a reliable result. Also, the identifying the factors / feature importance, data analysis would be really challenging. Especially when it comes to data analysis, visualizing data with more variables at once is a big challenge.
# >
# > Example - Any health care related dataset to predict a disease would have many features like the patient details(age, gender, bmi, location), patient lab results(blood pressure, hemoglobin and n number of lab results), testing date. Medical records generally comes with huge number of clinical lab values, where the curse of dimentionality is a common challenge.
# >
# > Dimensionality Reduction methods like PCA(transforms high dimensional data to new low dimensional data) , Feature Selection using knn(selecting only features that are important for modelling) could be used to work with dataset with high dimensions
#
# - Explain why the relationship between model error and complexity differs when patterns are examined using training and test datasets.
#
# > **_Answer:_**  Complex models tend to perform better on the training data , as the model parameters are adjusted to fit the training datapoints. Hence the model error rate would be less in training dataset.
# >
# > When the same complex model is tested on test dataset, if the model is tuned to capture the error data points as well, it will impact the performance and hence the model error would increase in the test dataset.
#
# - To the best of your knowledge, distinguish between training, test, and validation datasets. Briefly describe the importance of each in the context of Machine Learning.
#
# > **_Answer:_**  Training Dataset- The dataset the model get trained on. The model tries to learn the relationships / patterns from the training dataset. When the dataset has more features, the training dataset must be huge, so that the model can learn from the dataset. Usually 75- 80% of the dataset is used for training
# >
# > Test Dataset - The final unseen dataset on which the model will evaluated for the final performance. When the testing score reduces when compared to training score, we can say that the model is overfitting the data. 20% of the dataset will be used for testing which covers all the scenarios.
# >
# > Validation Dataset - This dataset is part of the development process and it is used for evaluating the performance while fine-tuning the models. When the model is initially trained and tested on validation dataset, if the performance drops in the validation drops, the model will be retrained with fine- tuning the model parameters. The validation dataset will be seen again for further model evaluation, but the model will not learn from the validation dataset. Once the model is trained on training dataset and evaluated on validation dataset and fine tuned, it will evaluated on the test data for once to evaluate the final performance. Validation dataset would be 10 - 15% of the total dataset.
#
# - Briefly discuss the consequences of overfitting and underfitting.
#
# > **_Answer:_**  Overfitting is a situation when the model tries to follow the dataset more closely and capturing the noise, instead of generalizing the data points. The model becomes very complex following the data point closely. Though the training score would be good, the testing score drops significantly impacting the model performance. We can use a less complex models, with proper feature selection to overcome the overfitting problem.
# >
# > Underfitting is when the model fails to capture the relationship in the dataset. This happens when the model is too simple and fails to learn from the dataset leading to poor performance in both training and test dataset. To overcome this, we can use more complex models without simple assumptions, with enhanced features and less regularization.

# %% [markdown]
# #### Question 3
#
# Explain whether each of the scenarios presented below is a classification or regression problem. Indicate whether the situation is mostly interested in conducting inference (explaining patterns) or prediction. Finally, indicate the number of observations (n) and features (p) associated with each of the .
#
# - We collect a set of data on the top 500 firms in the US. For each firm we record profit, number of employees, industry and the CEO salary. We are interested in understanding which factors affect CEO salary.
#
# > **_Answer:_**  Regression Problem. As we interested in the factors affecting CEO salary(quantitative measure), it is an Inference  .n = 500. p = 3 (profit, number of employees, industry)
#
# - We are considering launching a new product and wish to know whether it will be a success or a failure. We collect data on 20 similar products that were previously launched by different companies. For each product we have recorded its type, whether it was a success or failure, price charged for the product, marketing budget, competition price, and ten other variables.
#
# > **_Answer:_**  Classification problem to know if the new product is Success or failure. We are interested in Prediction . n = 20, p = 13 (success or failure, price charged for the product, marketing budget, competition price, and ten other variables)
#
# - We are interested in predicting the % change in the USD/Euro exchange rate in relation to the weekly changes in the world stock markets. Hence we collect weekly data for a given year. For each week we record the % change in the USD/Euro, the % change in the US market, the % change in the British market, and the % change in the German market.
#
# > **_Answer:_**  Regression problem to predict the quantitative value (exchange rate). Here we are doing Prediction. n = 52 (number of weeks in a year), p = 4 (the % change in the USD/Euro, the % change in the US market, the % change in the British market, and the % change in the German market)

# %% [markdown]
# #### Question 4
#
# Let's now revisit the bias-variance decomposition.
#
# - Provide a sketch of typical (squared) bias, variance, training error, test error, and irreducible (sometimes called Bayes error) error curves, on a single plot, as we go from less flexible statistical learning methods towards more flexible approaches. The x-axis should represent the amount of flexibility in the method, and the y-axis should represent the values for each curve. __There should be five main curves. Make sure to label each one__. Now, add two arrows (parallel to the X axis) indicating the direction of increase in over- and under-fitting, respectively. Finally, label the point, also in the X axis, where model complexity is optimal. [_Note: Please either draw your sketch on a piece of paper and then scan or take a photo. If you choose to do this, please submit the image file along with your homework. Feel free to find a way to insert the image into this file. :)_].
#
# > **_Answer:_**  ![Flexibility graph.jpeg](attachment:7ffee01d-33f0-49a4-83dc-f93bc345e593.jpeg)
#
#
# - Explain what the conceptual importance of acknowledging the existence of irreducible error is in the context of Machine Learning.
#
# > **_Answer:_**  Irreducible errors is an error type that cannot reduced / minimized. it is due to randomness or natural variability in a system. No matter how better the model is, the test MSE cannot be reduced beyond the Irreducible error. So, it is important, to identify if the model is overfitting the data by more closely following and capturing the error as well. This can help in avoiding the model being over-fit
#
#
# - Finally, briefly explain why each of the __five curves__ has the shape displayed.
#
# > **_Answer:_**  Irreducible error - Constant across different flexibility as the error is inherent to the data
# >
# >  Bias - Decreases as the flexibility increases. bias refers to the error that is introduced by approximating a real-life problem, which may be extremely complicated, by a much simpler model.So increased flexiblity decreases the data as it tries to follow the data points closely without any assumptions about the data.
# >
# >  Variance - Increases as the flexibility increases as it follows the data more closely. Variance refers to the amount by which  f^ would change if we estimated it using a different training data set, so if the curve fits the observations very closely, changing any point may cause  f^  to change considerably, and so flexible models will have more variance.
# >
# > Training error - Decreases as the flexibility increases. This is because flexible models tries to follow the data more closely and hence the training error decreases.
# >
# > Test error - Decreases initially with flexibility. But after some point, the test error increases back forming (U shape). When the flexibility of model increases, it tries to fit the data more closely and hence overfits the data. So the test error initially decreases, and increases  back with the flexibility when it is overfitting the data.

# %% [markdown]
# #### Question 5
# You will now think of some real-life applications for statistical learning.
#
# - Describe three real-life applications in which classification might be useful. Describe the response variable, as well as the potential predictors. Is the goal of each application inference or prediction? Explain your answer.
#
# > **_Answer:_**  1. Predicting if a person has Covid or not. Response - Predicting Covid. Predictors - Age, Gender, test date, symptoms observed(cough, fever, shortness of breath), recent contact to covid patients, travelled recently. Goal is Prediction
# >
# >  2. Telecom Customer Churn Prediction. The goal is to classify if the customer would likely to be churned or not based on customer activities like money spent, time spent , plan , status, complains raised. This is an inference and prediction application which can be used to predict if the customer will churn or not and identify various factors which causes the customer churn.
# >
# > 3. Customer Segmentation - groups the similar customer , so that any marketing strageties or advertisement could be implemented for each of the group. Response/ target -  Identify the customer group. Prediction - customer age, amount spent on each purchase, frequency of purchase,  products purchase, quantity purchased, location. Goal - Prediction and Inference
#
# - Describe three real-life applications in which regression  might be useful. Describe the response, as well as the predictors. Is the goal of each application inference or prediction? Explain your answer.
#
# > **_Answer:_**  1. Prediction of house values. The goal is to predict the house value(response) using various features/ predictors like number of rooms, total square feet, location, accessibility to highways, amenities , near to school zone, etc. The goal is to predict the house values.
# >
# > 2. Predicting Insurance cost billed by health Insurance - The response variable is insurance charge. Predictors could be age, sex, location, smoker, bmi, Number of children covered. Goal - Prediction
# >
# > 3. Predicting the Income of a person - The response variable is income, and the predictors could be age, education level, number of degrees earned, university where he studied, industry . This is a prediction application.

# %% [markdown]
# #### Question 6
#
# Let’s now review some ethical considerations associated with the development and implementation of Machine Learning algorithms. Please answer each question with as much detail as possible (one or two short paragraphs per question should suffice). Feel free to conduct additional research if you think it’s necessary. I’m looking for well-supported arguments. Your grade won’t be based on whether the instructor and TA agrees or disagrees with your position. Instead, do your best to provide a thoughtful and clear answer.
#
# - From your perspective, describe how unbiased must an algorithm be before it can be deployed in the “real world”? Is that level commonly achieved, discussed, or examined?
#
# > **_Answer:_**  Ideally the model must be unbiased as much as possible, at the same time not missing the reality. It highly depends on the training data and how the model is trained. If the training data is biased and a specific category being overrepresented, the trained model would end up being biased. We should take appropriate data pre - processing to control the bias in the training dataset.
# > For instance, consider a dataset collected from a health care company operating only in the USA. Trained model would be more biased towards US patients, the model might actually perform good for US patients and generate low accuracy for patients from China / Asia. This would result in a high risk situation where the patients are not diagonised properly.  Or, Recruiting assistance model trained on data overrepresented with male applicants. Such model would be biased and would be unfavorable for the women applicants selection rate.
# >
# > The "real world" algorithm struggles to achieve the unbiased state, but not all the models succeeds with achieving the unbiased state.
# > Another instance of Gemini which was recently launched by Google, where the model was trained to be avoid the bias towards the white race. But, it ended up being 'anti-white' biased model and failed to reflect the reality. When Gemini was queried for a image of US senator, it generated images of Black and Native American womens, which is completely inaccurate while trying to handle the Bias.
#
#
# - Research labs and companies generally invest the most in improving and developing ML algorithms. Do you think that society in general should also have immediate and equal access to these developments and to their benefits? How would you balance these two goals (e.g. profit and well-being)? Similarly, do you think ML already affects (or will affect) inequalities?
#
# > **_Answer:_**  I think society should not have immediate access to the developments. Companies and Research Labs invest in a lot of money in a more structured way, to handle such high-risk and high-reward projects with a lot of efficient human resources to work in the advancement of the technology. If these developments were immediately made available for public, it would generate no income for the companies for the investments and efforts made, which provides no motivation for investment in technology advancement. Companies uses patents, licenses to generate income from the investments made on these high risk projects. _Society should be allowed for the basic version access for free, and paid advanced version_ which will benefit the society to utilize the latest technology advancement. Also, allowing early and immediate access may introduce more security vulnerability, privacy violations. So, using controlled limited access can eliminating such ethical issues.
# >
# > Yes, ML already affects inequality in many ways - Automation through ML may cut down the jobs of many low-skill worker, which will further widen the economic gap and cause inequality. Though ML may generate many employment opportunities, but it would not be accessible for the low-skill worker as these opportunities may require high technology skills, which would further broaden the gap.
# > Also, ML can aggrevate the bias present in the existing data, causing inequalities in various sectors like healthcare, employment hiring, credit scoring. Proper measures should be taken to address the bias, before the ML algorithms are made available to the real world.
#
# - What do you see as a solution for problems associated with increasing automation and efficiency, both currently and in the future?
#
# > **_Answer:_**  Though automation helps with reducing a lot of manual efforts and saving time. There are several problems which arise with increasing automation
# >
# > Maintainence
# >  1. In terms of code changes / updates - Automation is not an one type job. Automation test scripts needs to be constantly updated to keep them in sync with the latest changes required.
# >  2. Version Upgrades - Not only maintainence based on the requirement changes, software version keeps updating and the automation scripts also need to be in sync with the version upgrades. Missing a major security software updates could lead to **Security Vulnerability**.
# >
# > Solution:  Proper cost-benefit analysis should be conducted, before automating any work. Maintainence will be ongoing task and there will be huge cost overhead associated with it.
#
# > Server load - There could be a lot of automation tasks which gets created to eliminate the minor tasks. But this will increase the server load and impact the performance of all the other tasks.
# >
# > Solution: Resource needs to be allocated to periodically assess the usage of the existing automation. Proper estimation has to be done before adding and removing the automation. So, this would help in maintaining the server load and handling the cost associated with that.
#
# >
# > Cost Implications - Because of the increased automation, there would be lot of cost involved in developing and maintaining it over time. Because of the increased cost associated in maintaining the automation, value assessment needs to be done periodically.
# >
# > Solution: Frequent value assessment needs to be done to see if all the automations which were created are still useful.
#
# >
# > Data Quality Assurance - Automation just picks up the input data and generates the output based on the requirement. But if the input data has significant data quality issues, the output would be wrong. Automation cannot address the data quality issues.
# >
# > Solution : Proper data quality assurance pipeline must be in place to address the Quality assurance of the data.
#
#
# - We discussed different trade-offs between models in class – one of these was related to model interpretability. Why do you think it is important for machine learning models to be interpretable? Provide at least two reasons. Among the reasons that you listed, which one do you believe is the most important? Explain.
#
# > **_Answer:_**
# >  1. Reliability and Trust - Model interpretability provides the various factors which influence the model output. This will help in trusting the model and hence can ensure that model predictions are reliable
# >  2. Collaboration - Model interpretability helps in communicating the usage of model to business / stake holders. This can help in providing any marketing / advertising strategy which can benefit the business.
# >  3. Fixing Issues - Because of the fact that we know how the model works and various factors involved in model prediction. It is easy to identify any bugs and fixing it in advance.
# >
# >  Collaboration is one of the key aspect which is important for the Data scientist to better communicate the results of the model to business. This will help in improving the business and propose various strategies to benefit the business.
#
# - Now, between model performance and model interpretability: which of these two qualities do you think is more important. Explain.
#
# > **_Answer:_**  Both the parameters are important, it highly depends on the objective of the Algorithm.  Model performance determines how accurate the model is, in predicting the targets. This parameter would be highly beneficial in case of a prediction problem and the goal is to have a model which generates better prediction. Model interpretability gives an inference on various factors which influences the target value, and this would be an important parameter in the inference application. We can take two situation to understand this better.
# >
# > Case 1 : Prediction of car prices(target) based on various predictors like year of purchase,  number of claims , location, mileage , miles driven. If the goal is to predict only car prices, model performance would take precedence. If the model is able to provide a good performance, then the objective is met. We are not worried about the model interpretability.
# >
# > Case 2: Prediction of heart attack and various factors which could cause heart attacks. Here the target variable is predicting heart attack and the predictors could be patients clinical lab values, patient details. Here the Model interpretability takes more precedence. Even though the model performance is very good in predicting whether the patient is likely to get a heart attack. It will not be useful if the model is not interpretable. The model should interpret the factors which influenced the model to predict the heart attack. In such high risk applications, model interpretability plays a major role.
# >
# > So, In conclusion, It would be useful to explain why the model/algorithm works in a specific way. For that, model interpretability is a key to understand the model better.
#
#
# - Particular examples in history show that different algorithms and datasets were originally developed/simulated/compiled with goals related to increasing systemic inequalities. For instance, let’s take a quick look at the _iris_ dataset (__Fisher 1936__). First, how many hits do you get after searching for _iris_ dataset tutorial in Google (feel free to try any similar or more systematic search queries)? Based on this search, list at least two different modern uses of the dataset. Now, go over __Kozak & Łotocka (2013)__ and briefly talk about the biological realism of the dataset. Briefly comment on your thoughts related to why _Annals of eugenics_ showed interested in this dataset. Finally, given the widespread availability of data, do you think that the very frequent use of the _iris_ dataset in the field sends a particular message to society?
#
# Kozak, M., & Łotocka, B. (2013). __What should we know about the famous Iris data__. Current Science, 104(5), 579-580.\
# Fisher, R. A. (1936). __The use of multiple measurements in taxonomic problems__. Annals of eugenics, 7(2), 179-188.
#
# > **_Answer:_**  Searching for _iris_ dataset tutorial gave a large number of results showing the popularity of the _iris_dataset in the field of machine learning. The dataset was used
# > 1. To explore various _multi-class classification_ algorithm in the supervised learning like Support vector machine, Linear Discriminant Analysis K-nearest neighbours to classify the iris flowers  .
# > 2.  To understand how to conduct _Exploratory Data Analysis(EDA)_ on a dataset. Because of the simplicity of the dataset with 5 columns and 150 records. This would be an ideal dataset for beginners to better understand the ML and statistics topic.
#
# >__Kozak & Łotocka (2013)__ talks about the many problems associated with the iris dataset. The dataset provides four features(length and width of the petal and  sepal ). of the three iris flower species  The paper talks about the biological realism of the iris flowers, argues that the dataset oversimplifies the broader range of features. Though the ML EDA on Iris dataset shows clear differentiation between the 3 species, it doesnot reflect the biological complex and features in reality. Hence ML models built on the Iris dataset does not generalize well with the real world data.
#
# >Annals of Eugenics aimed to demonstrate the application of discriminant analysis in the taxonomical problem. Because of the simplicity and limited features and species, Fisher used iris data for classifying and analysing biological data.
# >
# >The widespread and frequent use of iris dataset is primarily because of the simplicity of the dataset and how it aids in the foundational learning in the field of machine learning. As the dataset doesnot reflect the reality of the complex diversity in the iris species, the ML field should consider a more viable, complex dataset matching the reality to showcase the power of Machine Learning algorithm, as the real world dataset is more complex than what is presented with the iris dataset. Sticking to Iris dataset gives sense of inability / stagnation in making progress to complex data in ML field to the society.

# %% [markdown]
# ### Applied

# %% [markdown]
# #### Question 7 (421/521)
#
# This exercise relates to the `College` data set, which can be found in the file `College.csv`. It contains a number of variables for 777 different universities and colleges in the US. The variables are:
#
# - `Private` : Public/private indicator
# - `Apps` : Number of applications received
# - `Accept` : Number of applicants accepted
# - `Enroll` : Number of new students enrolled
# - `Top10perc` : New students from top 10 % of high school class
# - `Top25perc` : New students from top 25 % of high school class
# - `F.Undergrad` : Number of full-time undergraduates
# - `P.Undergrad` : Number of part-time undergraduates
# - `Outstate`  : Out-of-state tuition
# - `Room.Board` : Room and board costs
# - `Books` : Estimated book costs
# - `Personal` : Estimated personal spending
# - `PhD` : Percent of faculty with Ph.D.’s
# - `Terminal` : Percent of faculty with terminal degree
# - `S.F.Ratio` : Student/faculty ratio
# - `perc.alumni` : Percent of alumni who donate
# - `Expend` : Instructional expenditure per student
# - `Grad.Rate` : Graduation rate
#
#
# Use the `read_csv()` function in *pandas* library to read the data. Make sure that you have the directory set to the correct location for the data. Note that if you’re not interested in downloading the dataset (which would actually make your submission more reproducible), you could simply read the dataset directly from the website using `read_csv()`. The dataset can be found in the following link: https://book.huihoo.com/introduction-to-statistical-learning/College.csv.
#
# - Read dataset and save it as `college`.

# %%
# BEGIN SOLUTION
import pandas as pd
college = pd.read_csv("College.csv")
college
# END SOLUTION
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %% [markdown]
# - Use the `describe()` function to produce a numerical summary of the variables in the data set.

# %%
# BEGIN SOLUTION
college.describe()
# END SOLUTION
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# - Produce a scatterplot matrix of the first ten columns or variables of the data using the `pandas.plotting.scatter_matrix()` function or another suitable method.

# %%
# BEGIN SOLUTION
import seaborn as sns
import matplotlib.pyplot as plt 

pd.plotting.scatter_matrix(college, figsize=(12,12))

# we can also use seaborn pairplot for the same graph
#sns.pairplot(college[college.columns[2:12]])
# END SOLUTION

# %% [markdown]
# - Create side-by-side boxplots of `Outstate` versus `Private` using `matplotlib.pyplot` functions or another suitable method.

# %%
# BEGIN SOLUTION

college.boxplot(column = 'Outstate', by = 'Private')
# END SOLUTION

# %% [markdown]
# - Create a new binary variable, called `Elite`, by binning the `Top10perc` variable to `college.` We are going to divide universities into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50%.

# %%
# BEGIN SOLUTION
#Create a new variable `Elite` based on `Top10perc`
college['Elite'] = [True if x > 50 else False for x in college['Top10perc']]
college[['Elite','Top10perc']]
# END SOLUTION
# Out:
#      Elite  Top10perc
# 0    False         23
# 1    False         16
# 2    False         22
# 3     True         60
# 4    False         16
# ..     ...        ...
# 772  False          4
# 773  False         24
# 774  False         34
# 775   True         95
# 776  False         28
#
# [777 rows x 2 columns]

# %% [markdown]
# - Use the `describe()` function or another suitable method to determine the number of elite universities. Then, create side-by-side boxplots of `Outstate` versus `Elite`.

# %%
# BEGIN SOLUTION
#shows number of universities which are 'Elite' and 'Not Elite'
print("Number of elite universities ", college['Elite'].value_counts().iloc[1])
# value_counts shows 78 universities are Elite
# Out:
# Number of elite universities  78

# %%
# plot Outstate vs Elite
college.boxplot(column = 'Outstate', by = 'Elite')
# END SOLUTION
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %% [markdown]
# - Produce some histograms with diﬀering numbers of bins for a few of the quantitative variables. Use any functions you find suitable.

# %%
# BEGIN SOLUTION
#create subplot for multiple histogram
fig, ax = plt.subplots(2, 2)


#plot1  Histogram of Apps for break = 100
ax[0, 0].hist(college['Apps'],bins=100)
ax[0, 0].set_title("Hist of Apps - Breaks 100")


#plot1  Histogram of Apps for break = 50
ax[0, 1].hist(college['Apps'],bins=50)
ax[0, 1].set_title("Hist of Apps - Breaks 50")



ax[1, 0].hist(college['Outstate'],bins=50)
ax[1, 0].set_title("Outstate")


ax[1, 1].hist(college['Expend'],bins=50)
ax[1, 1].set_title("Expend")
plt.tight_layout()
# END SOLUTION

# %% [markdown]
# - Continue exploring the data, and provide a brief summary of what you discover. Some quick ideas: (1) explore graduation rates and briefly talk about what might be driving differences between universities. (2) Compare instructional expenditure per student and graduation rates.

# %%
# BEGIN SOLUTION
sns.scatterplot(x = "PhD", y = "Grad.Rate", hue = "Private", data= college);
# END SOLUTION

# %%
sns.scatterplot(x = "S.F.Ratio", y = "Grad.Rate", hue = "Private", data= college);

# %%
sns.scatterplot(x = "Expend", y = "Grad.Rate", hue = "Private", data= college);

# %% [markdown]
# **Observations**
#  1. Apps data histogram shows that it is highly skewed. Most universities received 500 or less application.
#  2. Out-of-state tuition fee is normally distributed ranging between 20k - 50k
#  3. Instructional Expenditure per student is skewed and it is less than 10k in most universities
#  4. Graduation rate is correlated with the Number of faculty with PhD. This shows if the university has more faculty with PhD, the graduation rate will be more
#  5. Private universities has more faculty with PhD
#  6. Student to Faculty Ratio(S.F.ratio) is less in Private University. When the student to faculty ratio is more, the graduation rate is decreasing.
#
#     This shows negative correlation between S.F.ratio and Graduation Rate.

# %% [markdown]
# - Are there any other features, not taken into account in the dataset, that you think might be important for understanding whether a school is classified as elite or not?

# %%
# BEGIN SOLUTION
sns.boxplot(x= "Elite", y = "Expend", data= college)
# END SOLUTION
# Out:
# <Axes: xlabel='Elite', ylabel='Expend'>

# %%
sns.boxplot(x= "Elite", y = "S.F.Ratio", data= college)
# Out:
# <Axes: xlabel='Elite', ylabel='S.F.Ratio'>

# %%
sns.boxplot(x= "Elite", y = "perc.alumni", data= college)
# Out:
# <Axes: xlabel='Elite', ylabel='perc.alumni'>

# %%
sns.boxplot(x= "Elite", y = "Accept", data= college)
# Out:
# <Axes: xlabel='Elite', ylabel='Accept'>

# %% [markdown]
# There are many features like Instructional Expenditure (`Expend`), Student Faculty Ratio(`S.F.Ratio`), Percentage of alumni who donate(`Perc.alumni`) which are in the dataset which defines the Elite univerisity.
#
# Including Features like `Selection Rate` in university which might be highly beneficial in determining the elite university.
#
# Selection Rate (S.R) = No. of Students Accepted  / Number of students applied

# %%
college['Selection.Rate'] =  college['Accept'] / college['Apps']
college[['Selection.Rate', 'Elite']]
# Out:
#      Selection.Rate  Elite
# 0          0.742169  False
# 1          0.880146  False
# 2          0.768207  False
# 3          0.836930   True
# 4          0.756477  False
# ..              ...    ...
# 772        0.689577  False
# 773        0.921388  False
# 774        0.913209  False
# 775        0.229145   True
# 776        0.620609  False
#
# [777 rows x 2 columns]

# %%
sns.boxplot(x= "Elite", y = "Selection.Rate", data= college)
# Out:
# <Axes: xlabel='Elite', ylabel='Selection.Rate'>

# %% [markdown]
# The above graph clearly shows that **Elite** university have *very low Selection Rate* . Adding `Selection.Rate` to the dataset will help in differentiating the Elite universities.

# %% [markdown]
# #### Question 8

# %% [markdown]
# This exercise involves the `auto` data, which can be found in the file `Auto.data`. Read the data and remove missing values.

# %%
# BEGIN SOLUTION
auto = pd.read_table('auto.data', sep= '\\s+')
auto.head()
# END SOLUTION
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0    70
# 1  15.0          8         350.0      165.0  3693.0          11.5    70
# 2  18.0          8         318.0      150.0  3436.0          11.0    70
# 3  16.0          8         304.0      150.0  3433.0          12.0    70
# 4  17.0          8         302.0      140.0  3449.0          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
auto.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
import numpy as np
#Replacing `?` with `NA`
auto.replace('?', np.nan, inplace=True)

# %%
auto.dropna(inplace= True)

# %%
auto.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %%
#converting the type of horsepower to float 
auto['horsepower'] = auto['horsepower'].astype("float")

# %% [markdown]
# - Which of the predictors are quantitative, and which are qualitative?
# > **_Answer:_**  `Quantitative predictors` - mpg,cylinders,displacement,horsepower,weight, acceleration, year
# > `Qualitative predictors` - origin, name.

# %%
Quantitative_pred = ['mpg', 'cylinders','displacement','horsepower','weight','acceleration', 'year']
auto[Quantitative_pred]
auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight          float64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %% [markdown]
# - What is the range of each quantitative predictor?

# %%
# BEGIN SOLUTION
#Generates the range for each column
auto[Quantitative_pred].apply(lambda x: x.max() - x.min())

# END SOLUTION
# Out:
# mpg               37.6
# cylinders          5.0
# displacement     387.0
# horsepower       184.0
# weight          3527.0
# acceleration      16.8
# year              12.0
# dtype: float64

# %% [markdown]
# - What is the mean and standard deviation of each quantitative predictor?

# %%
# BEGIN SOLUTION
#Generates mean of each column
auto[Quantitative_pred].apply(lambda x: x.mean())
# END SOLUTION
# Out:
# mpg               23.445918
# cylinders          5.471939
# displacement     194.411990
# horsepower       104.469388
# weight          2977.584184
# acceleration      15.541327
# year              75.979592
# dtype: float64

# %%
#Generates standard deviation of each column
auto[Quantitative_pred].apply(lambda x: x.std())
# Out:
# mpg               7.805007
# cylinders         1.705783
# displacement    104.644004
# horsepower       38.491160
# weight          849.402560
# acceleration      2.758864
# year              3.683737
# dtype: float64

# %% [markdown]
# - Now remove the 10th __through__ 85th observations from `auto`. Save this as a new object called `auto2`. What is the range, mean, and standard deviation of each predictor in `auto2`?

# %%
# BEGIN SOLUTION
auto2 = auto.drop(auto.index[10:85])
# END SOLUTION

# %%
#range of auto2
auto2[Quantitative_pred].apply(lambda x: x.max() - x.min())
# Out:
# mpg               35.6
# cylinders          5.0
# displacement     387.0
# horsepower       184.0
# weight          3348.0
# acceleration      16.3
# year              12.0
# dtype: float64

# %%
# BEGIN SOLUTION
#Generates mean of each column in auto2
auto2[Quantitative_pred].apply(lambda x: x.mean())
# END SOLUTION
# Out:
# mpg               24.374763
# cylinders          5.381703
# displacement     187.880126
# horsepower       101.003155
# weight          2938.854890
# acceleration      15.704101
# year              77.123028
# dtype: float64

# %%
#Generates standard deviation of each column
auto2[Quantitative_pred].apply(lambda x: x.std())
# Out:
# mpg               7.872565
# cylinders         1.658135
# displacement    100.169973
# horsepower       36.003208
# weight          811.640668
# acceleration      2.719913
# year              3.127158
# dtype: float64

# %% [markdown]
# - Using the full data set (`auto`), investigate the predictors graphically, using scatterplots or other tools of your choice. Create some plots highlighting the relationships among the predictors. Briefly comment on your findings.

# %%
# BEGIN SOLUTION
sns.pairplot(auto)
# END SOLUTION

# %% [markdown]
# > **_Answer:_**  The pairplot shows the relationship among all the features.
# > 1. Cylinders and displacement is highly positive correlated. When number of cylinder increases, the engine displacement increases.
# > 2. Cylinders and  horsepower are positively correlated. As the number of cylinders increases, the horsepower increases.
# > 3. Cylinders and weight are positively correlated. Cars with more numbers of cylinders are mostly high in weight.
# > 4. So, Cylinders, displacement, horsepower and weight are positively correlated with each other.

# %% [markdown]
# - Suppose that we were interested in predicting gas mileage (`mpg`) on the basis of the other variables. Do your plots suggest that any of the other variables might be useful in predicting `mpg`? Justify your answer.

# %%
auto[Quantitative_pred].corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# year          0.580541  -0.345647     -0.369855   -0.416361 -0.309120
#
#               acceleration      year
# mpg               0.423329  0.580541
# cylinders        -0.504683 -0.345647
# displacement     -0.543800 -0.369855
# horsepower       -0.689196 -0.416361
# weight           -0.416839 -0.309120
# acceleration      1.000000  0.290316
# year              0.290316  1.000000

# %%
# BEGIN SOLUTION
sns.heatmap(auto[Quantitative_pred].corr(), cmap="YlGnBu", annot=True) 
# END SOLUTION
# Out:
# <Axes: >

# %% [markdown]
# > **_Answer:_**  mpg is highly negative correlated with Cylinders, displacement, horsepower and weight. So these predictors could be helpful in predicting the mpg..

# %% [markdown]
# #### Question 9

# %% [markdown]
# - This exercise involves the `Boston` housing data set. To begin, load in the `Boston` data set from `Boston.csv'.

# %%
# BEGIN SOLUTION
Boston = pd.read_csv("Boston.csv",usecols  = ['crim','zn','indus','chas','nox','rm','age','dis','rad','tax','ptratio', 'lstat', 'medv'])
Boston.head()
# END SOLUTION
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %% [markdown]
# - How many rows are in this data set? How many columns? What do the rows and columns represent?

# %%
# BEGIN SOLUTION
print("Number of Rows", Boston.shape[0])
print("Number of Columns", Boston.shape[1])
# END SOLUTION
# Out:
# Number of Rows 506
# Number of Columns 13

# %% [markdown]
# > **_Answer:_**  Boston Dataset contains the housing values in various suburbs in Boston.
# >  - Rows represent the housing value in a particular suburb.
# >  - Columns represent various parameter like Crime Rate, Nitrogen oxide concentration which determines the housing values in each suburb.

# %% [markdown]
# - Make some pairwise scatterplots of the predictors (columns) in this data set. Describe your findings. Note that there’s a ton of things that you can comment on. Please select only one or two aspects that you think are relevant.

# %%
# BEGIN SOLUTION
sns.pairplot(Boston)
# END SOLUTION

# %% [markdown]
# > **_Answer:_**
# > 1. Accessibility to radial highways(rad) and full-value property tax(tax) are positively correlated. So, more the close to highways, higher the tax rate.
# > 2. Proportion of owner-occupied units built prior to 1940(Age) and weighted mean of distances to five Boston employment centres(dis) are negatively correlated. Recent dwellings are far from the city employment centres..

# %% [markdown]
# - Are any of the predictors associated with per capita crime rate? If so, explain the relationship.

# %%
# BEGIN SOLUTION

sns.scatterplot(x = "rad", y = "crim", data= Boston).set(title = "Crime Rate vs Accessibility to highways" )
# END SOLUTION
# Out:
# [Text(0.5, 1.0, 'Crime Rate vs Accessibility to highways')]

# %%
sns.scatterplot(x = "crim", y = "rad", data= Boston).set(title = "Crime Rate vs Accessibility to highways" )
# Out:
# [Text(0.5, 1.0, 'Crime Rate vs Accessibility to highways')]

# %%
sns.scatterplot(x = "dis", y = "crim", data= Boston).set(title = "Crime Rate vs weighted mean of distances to five Boston employment centres" )
# Out:
# [Text(0.5, 1.0, 'Crime Rate vs weighted mean of distances to five Boston employment centres')]

# %%
sns.heatmap(Boston.corr(), cmap="YlGnBu", annot=True)
# Out:
# <Axes: >

# %% [markdown]
# > **_Answer:_**
# > Crime Rate is weak to moderate correlation with the other predictors
# > 1. The Crime Rate vs Accessibility to highways graph shows that the relationship between crime rate and Accessiblity to radial highways. Crime rate is very low if the suburb has lower index of accessibility to radial highways. When the suburb has higher index of accessibility to radial highways, the crime rate is increasing.
# > 2. The Crime Rate vs Median value of Home graph shows that Crime rate is more common in low value property suburb. Although some crime rate is seen in more expensive property suburb.
# > 3. Crime Rate shows relationship.

# %% [markdown]
# - Do any of the census tracts of `Boston` appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.

# %%
sns.boxplot(x = "crim", data = Boston)
# Out:
# <Axes: xlabel='crim'>

# %%
# BEGIN SOLUTION
q1=Boston['crim'].quantile(0.25)
q3 = Boston['crim'].quantile(0.75)
IQR=q3-q1
print("First Quantile Q1", q1, "\n Third quantile Q3----",q3,"\n Inter-quantile Range IQR----", IQR, "\n Lower Outlier: -1.5*IQR" ,q1-1.5*IQR, "\n Upper Outlier: +1.5*IQR", q3+1.5*IQR)
Boston['crim']<(q1-1.5*IQR)
outliers = Boston[((Boston['crim']<(q1-1.5*IQR)) | (Boston['crim']>(q3+1.5*IQR)))]
outliers
# END SOLUTION
# Out:
# First Quantile Q1 0.08204499999999999
#  Third quantile Q3---- 3.6770825
#  Inter-quantile Range IQR---- 3.5950375
#  Lower Outlier: -1.5*IQR -5.31051125
#  Upper Outlier: +1.5*IQR 9.06963875
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 367  13.5222  0.0   18.1     0  0.631  3.863  100.0  1.5106   24  666
# 371   9.2323  0.0   18.1     0  0.631  6.216  100.0  1.1691   24  666
# 373  11.1081  0.0   18.1     0  0.668  4.906  100.0  1.1742   24  666
# 374  18.4982  0.0   18.1     0  0.668  4.138  100.0  1.1370   24  666
# 375  19.6091  0.0   18.1     0  0.671  7.313   97.9  1.3163   24  666
# ..       ...  ...    ...   ...    ...    ...    ...     ...  ...  ...
# 468  15.5757  0.0   18.1     0  0.580  5.926   71.0  2.9084   24  666
# 469  13.0751  0.0   18.1     0  0.580  5.713   56.7  2.8237   24  666
# 477  15.0234  0.0   18.1     0  0.614  5.304   97.3  2.1007   24  666
# 478  10.2330  0.0   18.1     0  0.614  6.185   96.7  2.1705   24  666
# ...

# %%
sns.boxplot(x = "tax", data = Boston)
# Out:
# <Axes: xlabel='tax'>

# %%
# BEGIN SOLUTION
q1=Boston['tax'].quantile(0.25)
q3 = Boston['tax'].quantile(0.75)
IQR=q3-q1
print("Q1", q1, "Q3----",q3,"IQR----", IQR, "-1.5*IQR" ,q1-1.5*IQR, "+1.5*IQR", q3+1.5*IQR)

tax_outliers = Boston[((Boston['tax']<(q1-1.5*IQR)) | (Boston['tax']>(q3+1.5*IQR)))]
tax_outliers
# END SOLUTION
# Out:
# Q1 279.0 Q3---- 666.0 IQR---- 387.0 -1.5*IQR -301.5 +1.5*IQR 1246.5
# Empty DataFrame
# Columns: [crim, zn, indus, chas, nox, rm, age, dis, rad, tax, ptratio, lstat, medv]
# Index: []

# %%
sns.boxplot(x = "ptratio", data = Boston)
# Out:
# <Axes: xlabel='ptratio'>

# %%
# BEGIN SOLUTION
q1=Boston['ptratio'].quantile(0.25)
q3 = Boston['ptratio'].quantile(0.75)
IQR=q3-q1
print("Q1", q1, "Q3----",q3,"IQR----", IQR, "-1.5*IQR" ,q1-1.5*IQR, "+1.5*IQR", q3+1.5*IQR)

pt_ratio_outliers = Boston[((Boston['ptratio']<(q1-1.5*IQR)) | (Boston['ptratio']>(q3+1.5*IQR)))]
pt_ratio_outliers
# END SOLUTION
# Out:
# Q1 17.4 Q3---- 20.2 IQR---- 2.8000000000000007 -1.5*IQR 13.199999999999998 +1.5*IQR 24.4
#         crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 196  0.04011  80.0   1.52     0  0.404  7.287   34.1  7.3090    2  329
# 197  0.04666  80.0   1.52     0  0.404  7.107   36.6  7.3090    2  329
# 198  0.03768  80.0   1.52     0  0.404  7.274   38.3  7.3090    2  329
# 257  0.61154  20.0   3.97     0  0.647  8.704   86.9  1.8010    5  264
# 258  0.66351  20.0   3.97     0  0.647  7.333  100.0  1.8946    5  264
# 259  0.65665  20.0   3.97     0  0.647  6.842  100.0  2.0107    5  264
# 260  0.54011  20.0   3.97     0  0.647  7.203   81.8  2.1121    5  264
# 261  0.53412  20.0   3.97     0  0.647  7.520   89.4  2.1398    5  264
# 262  0.52014  20.0   3.97     0  0.647  8.398   91.5  2.2885    5  264
# 263  0.82526  20.0   3.97     0  0.647  7.327   94.5  2.0788    5  264
# 264  0.55007  20.0   3.97     0  0.647  7.206   91.6  1.9301    5  264
# ...

# %% [markdown]
# > **_Answer:_**   The huge tail represented in dots in the box plot indicates  number of suburbs with very high crime rate. There are 66 suburbs with very high crime rate. There are no suburbs with particularly high tax rates.
# >
# > There are few suburbs with very low pt ratio which is indicated by few dots in the box plot. There are 15 suburbs as outliers with very low ptratio. There are no suburbs with very high ptratio

# %% [markdown]
# - How many of the census tracts in this data set bound the Charles river?

# %%
# BEGIN SOLUTION
print (" Number of census tract bound the Charles river", len(list(filter(lambda x: x == 1, Boston['chas']))))
#35 suburbs are charles river bound
# END SOLUTION
# Out:
#  Number of census tract bound the Charles river 35

# %% [markdown]
# - What is the median pupil-teacher ratio among the towns in this data set?

# %%
# BEGIN SOLUTION
print("median pupil-teacher ratio among the towns", Boston['ptratio'].median())
# median pupil-teacher ratio among the towns is 19.05
# END SOLUTION
# Out:
# median pupil-teacher ratio among the towns 19.05

# %% [markdown]
# - Which census tract of `Boston` has lowest median value of owner-occupied homes? What are the values of the other predictors for that census tract, and how do those values compare to the overall ranges for those predictors? Comment on your findings.

# %%
# BEGIN SOLUTION
Boston[Boston['medv'] == Boston['medv'].min()]

# END SOLUTION
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio  lstat  medv
# 398     20.2  30.59   5.0
# 405     20.2  22.98   5.0

# %%
pd.DataFrame({'range' : Boston.apply(lambda x: x.max() - x.min()), 'min' : Boston.apply(lambda x: x.min()), 'max' : Boston.apply(lambda x: x.max())})
# Out:
#              range        min       max
# crim      88.96988    0.00632   88.9762
# zn       100.00000    0.00000  100.0000
# indus     27.28000    0.46000   27.7400
# chas       1.00000    0.00000    1.0000
# nox        0.48600    0.38500    0.8710
# rm         5.21900    3.56100    8.7800
# age       97.10000    2.90000  100.0000
# dis       10.99690    1.12960   12.1265
# rad       23.00000    1.00000   24.0000
# tax      524.00000  187.00000  711.0000
# ptratio    9.40000   12.60000   22.0000
# lstat     36.24000    1.73000   37.9700
# medv      45.00000    5.00000   50.0000

# %% [markdown]
# > **_Answer:_**  Suburbs 398 and 405 have the lowest median value of owner-occupied homes.
# >
# > Census tract 399 has a medium crime rate, not chas river bound, close to boston employment centres(dis), high full-value property tax rate and low median value of owner occupied homes,
# >
# > whereas census tract 406 has a  high crime rate, not chas river bound, very old with most of the owner - occupied units built before 1940,close to boston employment centres(dis), high full-value property tax rate and low median value of owner occupied homes

# %% [markdown]
# - In this data set, how many of the census tracts average more than seven rooms per dwelling? More than eight rooms per dwelling? Comment on the census tracts that average more than eight rooms per dwelling.

# %%
# BEGIN SOLUTION
print("Number of the census tracts average more than seven rooms per dwelling", len(Boston[Boston['rm'] > 7]))
print("Number of the census tracts average more than eight rooms per dwelling", len(Boston[Boston['rm'] > 8]))

print("\n List of census tracts with average more than eight rooms per dwelling")
Boston[Boston['rm'] > 8]
# END SOLUTION
# Out:
# Number of the census tracts average more than seven rooms per dwelling 64
# Number of the census tracts average more than eight rooms per dwelling 13
#
#  List of census tracts with average more than eight rooms per dwelling
#         crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 97   0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2  276
# 163  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5  403
# 204  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# 224  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8  307
# 225  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8  307
# 226  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8  307
# 232  0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8  307
# 233  0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8  307
# 253  0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7  330
# ...

# %% [markdown]
# > **_Answer:_**  64 census tracts has an average of more than seven rooms per dwelling
# >
# > 13 census tracts has an average of more than eight rooms per dwelling
# >
# > Census tracts that average more than eight rooms per dwelling have a
# > 1.  very low crime rate,
# > 2.  most of them are not chas river bound except for 164 suburb,
# > 3.  most of suburbs have old owner -occupied units built prior to 1940 except for 254,
# > 4.  most of them with less weighted mean of distance to boston employment centres,
# > 5.  very less lower status population percent,
# > 6.  low to moderate full-value property tax rate,
# > 7.  high to very high median value of owner occupied units

# %% [markdown]
# ### Extra credit

# %% [markdown]
# Re-assessing the `Boston` dataset
#
# - The `Boston` dataset is now part of the standard training sets implemented in many libraries and packages across different languages (e.g. `scikit-learn` ["recently" deprecated] and `Tensorflow` in `Python`; `MASS` in `R`). Did any of the questions (or your answers) listed above raise any red flags about the dataset?

# %% [markdown]
# > **_Answer:_**  Boston dataset primarily talks about the housing prices in 506 suburbs. This dataset is too small and  limited for predicting the housing prices using ML model and it will not generalize well to the real world scenarios. With the limited data in hand, the model is overfit the data, rather than generalising to the real world.
# >
# > Boston dataset also misses out various other important features like school zone, public transportation connectivity, amenities nearby, which helps in predicting the house price.
# >
# > The dataset also includes ethically sensitive information like lower status of the population percentage(lstat), training on a model on such dataset would reinforce inequality in the final prediction of house prices.

# %% [markdown]
# - This dataset, originally published in __Harrison and Rubinfeld (1978)__, was primarily compiled to examine the effects of environmental factors in driving spatial patterns of the housing market. To date, different packages have implemented alternative versions of the features sampled in the dataset. Please compare the features (and their descriptions) in Table IV from the original study (__Harrison and Rubinfeld, 1978__) to the features used in the Book’s dataset (the one we used in this homework). If the two datasets are not equivalent in their features, briefly (1) discuss the potential motives behind these discrepancies, and (2) comment on whether dropping particular columns was the right solution? Feel free to comment on the potential differences (conceptual and social) associated with training models in each of these two datasets.
#
# Harrison Jr, D., & Rubinfeld, D. L. (1978). __Hedonic housing prices and the demand for clean air. Journal of environmental economics and management__, 5(1), 81-102.

# %% [markdown]
# > **_Answer:_**  Boston dataset has two features (`B` and `PART`) missing  comparing with the dataset published in **Harrison and Rubinfeld(1978)**.
# >
# > The feature `B` implies the black proportion of the population. Increased value in B will lower the median value of houses. This feature will introduce a bias in the dataset and raises Ethical concern. With the growing emphasis on fairness, ethics and Bias mitigation, it is a good practise to remove the Bias inducing feature like  `B`, ensuring the model built on the dataset will not biased.
# >
# >  The feature `PART` indicates the particulate concentrations relating to air pollution in the suburb. This feature is highly correlated with the `NOX` feature, both indicating the air pollution in the suburb. So, the `PART` feature is redundant and hence it can be dropped to meet the modern dataset standards.
# >
# > So, dropping both the features has a fair reason like removing redundant features and biased features to maintain the modern dataset standards.
